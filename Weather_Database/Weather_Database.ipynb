# %%
# Import the dependencies
import numpy as np
from citipy import citipy
import requests
import time
import pandas as pd

# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | te anau
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | carballo
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | candido de abreu
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | kahului
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | san cristobal
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | kysyl-syr
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | kholmogory
# Processing Record 24 of Set 1 | samarai
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | tateyama
# Processing Record 30 of Set 1 | macaiba
# Processing Record 31 of Set 1 | tessalit
# Processing Record 32 of Set 1 | goundam
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | sao joao da barra
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | kerteh
# City not found. Skipping...
# Processing Record 39 of Set 1 | vostok
# Processing Record 40 of Set 1 | pangnirtung
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | los llanos de aridane
# Processing Record 44 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 1 | cabra
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | ixtapa
# Processing Record 2 of Set 2 | roma
# Processing Record 3 of Set 2 | aberdeen
# Processing Record 4 of Set 2 | maridi
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | san policarpo
# Processing Record 8 of Set 2 | sawakin
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | mehamn
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 2 | bardiyah
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | coihaique
# Processing Record 20 of Set 2 | mudyuga
# City not found. Skipping...
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-georges
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | talisayan
# Processing Record 26 of Set 2 | lopukhiv
# Processing Record 27 of Set 2 | tenno
# Processing Record 28 of Set 2 | bilma
# Processing Record 29 of Set 2 | freeport
# Processing Record 30 of Set 2 | tezu
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | ornskoldsvik
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | prokudskoye
# Processing Record 35 of Set 2 | aykhal
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | ambulu
# Processing Record 39 of Set 2 | rawlins
# Processing Record 40 of Set 2 | sault sainte marie
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | bluefield
# Processing Record 45 of Set 2 | matara
# Processing Record 46 of Set 2 | rumilly
# Processing Record 47 of Set 2 | mayumba
# Processing Record 48 of Set 2 | walvis bay
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | batagay
# Processing Record 2 of Set 3 | dubti
# Processing Record 3 of Set 3 | fortuna
# Processing Record 4 of Set 3 | yumen
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | banda aceh
# Processing Record 7 of Set 3 | morondava
# Processing Record 8 of Set 3 | muskegon
# Processing Record 9 of Set 3 | teya
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | tucuman
# Processing Record 13 of Set 3 | margate
# Processing Record 14 of Set 3 | santa isabel do rio negro
# Processing Record 15 of Set 3 | lorengau
# Processing Record 16 of Set 3 | monrovia
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | cockburn town
# Processing Record 19 of Set 3 | belmonte
# Processing Record 20 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | huarmey
# Processing Record 24 of Set 3 | nakamura
# Processing Record 25 of Set 3 | tarko-sale
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | teguise
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | escarcega
# Processing Record 30 of Set 3 | gat
# Processing Record 31 of Set 3 | touros
# Processing Record 32 of Set 3 | barcelos
# Processing Record 33 of Set 3 | mindelo
# Processing Record 34 of Set 3 | ballina
# Processing Record 35 of Set 3 | imbituba
# Processing Record 36 of Set 3 | bani walid
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | kalevala
# Processing Record 39 of Set 3 | cairns
# Processing Record 40 of Set 3 | vila velha
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | christchurch
# Processing Record 45 of Set 3 | asopos
# Processing Record 46 of Set 3 | puerto leguizamo
# Processing Record 47 of Set 3 | rivadavia
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | maniitsoq
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | gazojak
# Processing Record 5 of Set 4 | surt
# Processing Record 6 of Set 4 | mayaky
# Processing Record 7 of Set 4 | rawah
# Processing Record 8 of Set 4 | pangkalanbuun
# Processing Record 9 of Set 4 | porbandar
# Processing Record 10 of Set 4 | puerto escondido
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | rosetta
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | myitkyina
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | agarak
# Processing Record 17 of Set 4 | zlitan
# Processing Record 18 of Set 4 | lakatoro
# Processing Record 19 of Set 4 | zhigansk
# Processing Record 20 of Set 4 | bredasdorp
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | itaituba
# Processing Record 23 of Set 4 | vao
# Processing Record 24 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 4 | ramanuj ganj
# Processing Record 26 of Set 4 | mogapinyana
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | huinan
# Processing Record 30 of Set 4 | oshogbo
# Processing Record 31 of Set 4 | suslovo
# Processing Record 32 of Set 4 | batticaloa
# Processing Record 33 of Set 4 | ayan
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | japura
# Processing Record 36 of Set 4 | mareeba
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint-joseph
# Processing Record 39 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 4 | porto velho
# Processing Record 41 of Set 4 | mont-de-marsan
# Processing Record 42 of Set 4 | north bend
# Processing Record 43 of Set 4 | praia da vitoria
# Processing Record 44 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 4 | deer lake
# Processing Record 46 of Set 4 | ryotsu
# Processing Record 47 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 4 | lokosovo
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | san rafael
# Processing Record 2 of Set 5 | celestun
# Processing Record 3 of Set 5 | kenitra
# Processing Record 4 of Set 5 | cabedelo
# Processing Record 5 of Set 5 | krasnoarmeysk
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | lyngseidet
# Processing Record 8 of Set 5 | byron bay
# Processing Record 9 of Set 5 | taldan
# Processing Record 10 of Set 5 | arraial do cabo
# Processing Record 11 of Set 5 | englehart
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | vardo
# Processing Record 14 of Set 5 | pochutla
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | seto
# Processing Record 17 of Set 5 | warri
# Processing Record 18 of Set 5 | vila
# Processing Record 19 of Set 5 | laramie
# Processing Record 20 of Set 5 | honningsvag
# Processing Record 21 of Set 5 | filadelfia
# Processing Record 22 of Set 5 | luan
# Processing Record 23 of Set 5 | dhanera
# Processing Record 24 of Set 5 | mlimba
# Processing Record 25 of Set 5 | tulun
# Processing Record 26 of Set 5 | finschhafen
# Processing Record 27 of Set 5 | muros
# Processing Record 28 of Set 5 | bilibino
# Processing Record 29 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 5 | vaitape
# Processing Record 31 of Set 5 | tual
# Processing Record 32 of Set 5 | antalaha
# Processing Record 33 of Set 5 | cotonou
# Processing Record 34 of Set 5 | erenhot
# Processing Record 35 of Set 5 | revelstoke
# Processing Record 36 of Set 5 | zabol
# Processing Record 37 of Set 5 | axim
# Processing Record 38 of Set 5 | jacareacanga
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | kamensk-uralskiy
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | caceres
# Processing Record 43 of Set 5 | san andres
# Processing Record 44 of Set 5 | mamallapuram
# Processing Record 45 of Set 5 | worland
# Processing Record 46 of Set 5 | castanhal
# Processing Record 47 of Set 5 | zapolyarnyy
# Processing Record 48 of Set 5 | san quintin
# Processing Record 49 of Set 5 | hualmay
# Processing Record 50 of Set 5 | halifax
# Processing Record 1 of Set 6 | new amsterdam
# Processing Record 2 of Set 6 | tarkwa
# Processing Record 3 of Set 6 | potiskum
# Processing Record 4 of Set 6 | east london
# Processing Record 5 of Set 6 | port alfred
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | sindal
# Processing Record 8 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 6 | cape coast
# Processing Record 10 of Set 6 | palmer
# Processing Record 11 of Set 6 | luanda
# Processing Record 12 of Set 6 | manakara
# Processing Record 13 of Set 6 | tucuma
# Processing Record 14 of Set 6 | ormara
# Processing Record 15 of Set 6 | kuloy
# Processing Record 16 of Set 6 | half moon bay
# Processing Record 17 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 6 | simao
# Processing Record 19 of Set 6 | xuddur
# Processing Record 20 of Set 6 | yueyang
# Processing Record 21 of Set 6 | saposoa
# Processing Record 22 of Set 6 | sioux lookout
# Processing Record 23 of Set 6 | asau
# Processing Record 24 of Set 6 | reisterstown
# Processing Record 25 of Set 6 | betlitsa
# Processing Record 26 of Set 6 | liverpool
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | flinders
# Processing Record 29 of Set 6 | seydi
# Processing Record 30 of Set 6 | broken hill
# Processing Record 31 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 6 | silvassa
# Processing Record 33 of Set 6 | esperance
# Processing Record 34 of Set 6 | ayios loukas
# City not found. Skipping...
# Processing Record 35 of Set 6 | sfantu gheorghe
# Processing Record 36 of Set 6 | tabory
# Processing Record 37 of Set 6 | mujiayingzi
# Processing Record 38 of Set 6 | athens
# Processing Record 39 of Set 6 | mattru
# Processing Record 40 of Set 6 | juneau
# Processing Record 41 of Set 6 | ko samui
# Processing Record 42 of Set 6 | charters towers
# Processing Record 43 of Set 6 | mao
# Processing Record 44 of Set 6 | luderitz
# Processing Record 45 of Set 6 | yurty
# Processing Record 46 of Set 6 | kalangala
# Processing Record 47 of Set 6 | okitipupa
# Processing Record 48 of Set 6 | bambous virieux
# Processing Record 49 of Set 6 | camacha
# Processing Record 50 of Set 6 | mana
# Processing Record 1 of Set 7 | istok
# Processing Record 2 of Set 7 | gizo
# Processing Record 3 of Set 7 | nikolskoye
# Processing Record 4 of Set 7 | konstantinovsk
# Processing Record 5 of Set 7 | san jose
# Processing Record 6 of Set 7 | rio gallegos
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | sangar
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | georgetown
# Processing Record 11 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 7 | raudeberg
# Processing Record 13 of Set 7 | high level
# Processing Record 14 of Set 7 | manado
# Processing Record 15 of Set 7 | aguas formosas
# Processing Record 16 of Set 7 | agadez
# Processing Record 17 of Set 7 | afua
# Processing Record 18 of Set 7 | colomi
# Processing Record 19 of Set 7 | tamandare
# Processing Record 20 of Set 7 | salinas
# Processing Record 21 of Set 7 | dingle
# Processing Record 22 of Set 7 | podhum
# Processing Record 23 of Set 7 | mount gambier
# Processing Record 24 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 7 | havre-saint-pierre
# Processing Record 26 of Set 7 | havoysund
# Processing Record 27 of Set 7 | dunedin
# Processing Record 28 of Set 7 | hamilton
# Processing Record 29 of Set 7 | narsaq
# Processing Record 30 of Set 7 | simoes
# Processing Record 31 of Set 7 | vatne
# Processing Record 32 of Set 7 | mancora
# Processing Record 33 of Set 7 | tarauaca
# Processing Record 34 of Set 7 | samaro
# Processing Record 35 of Set 7 | pudozh
# Processing Record 36 of Set 7 | umm kaddadah
# Processing Record 37 of Set 7 | hasaki
# Processing Record 38 of Set 7 | presidencia roque saenz pena
# Processing Record 39 of Set 7 | abu kamal
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | werdau
# Processing Record 42 of Set 7 | souillac
# Processing Record 43 of Set 7 | cartagena
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | atyrau
# Processing Record 46 of Set 7 | ambunti
# Processing Record 47 of Set 7 | upata
# Processing Record 48 of Set 7 | constitucion
# Processing Record 49 of Set 7 | college
# Processing Record 50 of Set 7 | tyup
# Processing Record 1 of Set 8 | abu samrah
# Processing Record 2 of Set 8 | avera
# Processing Record 3 of Set 8 | naze
# Processing Record 4 of Set 8 | ponta do sol
# Processing Record 5 of Set 8 | cururupu
# Processing Record 6 of Set 8 | salalah
# Processing Record 7 of Set 8 | kisangani
# Processing Record 8 of Set 8 | neya
# Processing Record 9 of Set 8 | polewali
# Processing Record 10 of Set 8 | abu zabad
# Processing Record 11 of Set 8 | haines junction
# Processing Record 12 of Set 8 | kurilsk
# Processing Record 13 of Set 8 | sao filipe
# Processing Record 14 of Set 8 | cap malheureux
# Processing Record 15 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 8 | marshall
# Processing Record 17 of Set 8 | bathsheba
# Processing Record 18 of Set 8 | wencheng
# Processing Record 19 of Set 8 | bakel
# Processing Record 20 of Set 8 | palaia fokaia
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 8 | aitape
# Processing Record 24 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 25 of Set 8 | alyangula
# Processing Record 26 of Set 8 | la ronge
# Processing Record 27 of Set 8 | vallenar
# Processing Record 28 of Set 8 | chimbote
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | longyearbyen
# Processing Record 31 of Set 8 | dunmore town
# Processing Record 32 of Set 8 | wairoa
# Processing Record 33 of Set 8 | parrita
# Processing Record 34 of Set 8 | temerloh
# Processing Record 35 of Set 8 | dukat
# Processing Record 36 of Set 8 | athabasca
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 40 of Set 8 | wicklow
# Processing Record 41 of Set 8 | salinopolis
# Processing Record 42 of Set 8 | muisne
# Processing Record 43 of Set 8 | sokoni
# Processing Record 44 of Set 8 | berekum
# Processing Record 45 of Set 8 | resen
# Processing Record 46 of Set 8 | kampene
# Processing Record 47 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 8 | alofi
# Processing Record 49 of Set 8 | buraydah
# Processing Record 50 of Set 8 | frontera
# Processing Record 1 of Set 9 | nouadhibou
# Processing Record 2 of Set 9 | general roca
# Processing Record 3 of Set 9 | claremore
# Processing Record 4 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 9 | lavrentiya
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | husavik
# Processing Record 8 of Set 9 | kiama
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 9 | ulladulla
# Processing Record 13 of Set 9 | montepuez
# Processing Record 14 of Set 9 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 15 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 9 | iquique
# Processing Record 17 of Set 9 | pacific grove
# Processing Record 18 of Set 9 | ekpoma
# Processing Record 19 of Set 9 | tongliao
# Processing Record 20 of Set 9 | yambio
# Processing Record 21 of Set 9 | goulburn
# Processing Record 22 of Set 9 | tenerife
# Processing Record 23 of Set 9 | baraut
# Processing Record 24 of Set 9 | rapid valley
# Processing Record 25 of Set 9 | eyl
# Processing Record 26 of Set 9 | olinda
# Processing Record 27 of Set 9 | resistencia
# Processing Record 28 of Set 9 | saskylakh
# Processing Record 29 of Set 9 | arroyo grande
# Processing Record 30 of Set 9 | aklavik
# Processing Record 31 of Set 9 | burica
# City not found. Skipping...
# Processing Record 32 of Set 9 | ippy
# Processing Record 33 of Set 9 | yenagoa
# Processing Record 34 of Set 9 | willmar
# Processing Record 35 of Set 9 | koppang
# Processing Record 36 of Set 9 | moyale
# Processing Record 37 of Set 9 | chapais
# Processing Record 38 of Set 9 | fort portal
# Processing Record 39 of Set 9 | amapa
# Processing Record 40 of Set 9 | chulman
# Processing Record 41 of Set 9 | victoria
# Processing Record 42 of Set 9 | kailua
# Processing Record 43 of Set 9 | champerico
# Processing Record 44 of Set 9 | hobyo
# Processing Record 45 of Set 9 | jati
# Processing Record 46 of Set 9 | najran
# Processing Record 47 of Set 9 | bengkulu
# Processing Record 48 of Set 9 | ostrovnoy
# Processing Record 49 of Set 9 | timizart
# Processing Record 50 of Set 9 | provideniya
# Processing Record 1 of Set 10 | verkhoyansk
# Processing Record 2 of Set 10 | antofagasta
# Processing Record 3 of Set 10 | uruguaiana
# Processing Record 4 of Set 10 | ojinaga
# Processing Record 5 of Set 10 | rincon
# Processing Record 6 of Set 10 | saint-francois
# Processing Record 7 of Set 10 | chaman
# Processing Record 8 of Set 10 | valencia
# Processing Record 9 of Set 10 | bambanglipuro
# Processing Record 10 of Set 10 | bondo
# Processing Record 11 of Set 10 | wladyslawowo
# Processing Record 12 of Set 10 | ulaangom
# Processing Record 13 of Set 10 | cayenne
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | domoni
# Processing Record 16 of Set 10 | solnechnogorsk
# Processing Record 17 of Set 10 | northam
# Processing Record 18 of Set 10 | segamat
# Processing Record 19 of Set 10 | verkhnya syrovatka
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | kaitangata
# Processing Record 22 of Set 10 | rudbar
# Processing Record 23 of Set 10 | lodja
# Processing Record 24 of Set 10 | karpathos
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | codrington
# Processing Record 27 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 10 | necochea
# Processing Record 29 of Set 10 | qasigiannguit
# Processing Record 30 of Set 10 | kaka
# Processing Record 31 of Set 10 | baykit
# Processing Record 32 of Set 10 | kyzyl-suu
# Processing Record 33 of Set 10 | namibe
# Processing Record 34 of Set 10 | chokurdakh
# Processing Record 35 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 10 | riosucio
# Processing Record 37 of Set 10 | alice springs
# Processing Record 38 of Set 10 | uk
# City not found. Skipping...
# Processing Record 39 of Set 10 | sisimiut
# Processing Record 40 of Set 10 | takoradi
# Processing Record 41 of Set 10 | joppatowne
# Processing Record 42 of Set 10 | geraldton
# Processing Record 43 of Set 10 | nampula
# Processing Record 44 of Set 10 | miri
# Processing Record 45 of Set 10 | gayeri
# Processing Record 46 of Set 10 | lubao
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | toro
# Processing Record 49 of Set 10 | namie
# Processing Record 50 of Set 10 | komsomolskiy
# Processing Record 1 of Set 11 | whitehorse
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | pozo colorado
# Processing Record 4 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 5 of Set 11 | hervey bay
# Processing Record 6 of Set 11 | clyde river
# Processing Record 7 of Set 11 | port blair
# Processing Record 8 of Set 11 | waddan
# Processing Record 9 of Set 11 | muroto
# Processing Record 10 of Set 11 | gweta
# Processing Record 11 of Set 11 | savannah bight
# Processing Record 12 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 11 | seybaplaya
# Processing Record 14 of Set 11 | santa cruz
# Processing Record 15 of Set 11 | gillette
# Processing Record 16 of Set 11 | olga
# Processing Record 17 of Set 11 | urusha
# Processing Record 18 of Set 11 | hofn
# Processing Record 19 of Set 11 | bhongir
# Processing Record 20 of Set 11 | midyat
# Processing Record 21 of Set 11 | narasannapeta
# Processing Record 22 of Set 11 | goderich
# Processing Record 23 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 24 of Set 11 | santa maria del oro
# Processing Record 25 of Set 11 | erzin
# Processing Record 26 of Set 11 | belyy yar
# Processing Record 27 of Set 11 | vila franca do campo
# Processing Record 28 of Set 11 | union hidalgo
# Processing Record 29 of Set 11 | changping
# Processing Record 30 of Set 11 | tubuala
# Processing Record 31 of Set 11 | diamantino
# Processing Record 32 of Set 11 | paka
# Processing Record 33 of Set 11 | aberfoyle
# Processing Record 34 of Set 11 | hargeysa
# Processing Record 35 of Set 11 | the pas
# Processing Record 36 of Set 11 | el cobre
# Processing Record 37 of Set 11 | taoudenni
# Processing Record 38 of Set 11 | kirakira
# Processing Record 39 of Set 11 | xiaolan
# Processing Record 40 of Set 11 | teguldet
# Processing Record 41 of Set 11 | progreso
# Processing Record 42 of Set 11 | nyaunglebin
# Processing Record 43 of Set 11 | callaguip
# Processing Record 44 of Set 11 | la serena
# Processing Record 45 of Set 11 | rio grande
# Processing Record 46 of Set 11 | urgut
# Processing Record 47 of Set 11 | la cumbre
# Processing Record 48 of Set 11 | klamath falls
# Processing Record 49 of Set 11 | quillota
# Processing Record 50 of Set 11 | faya
# Processing Record 1 of Set 12 | port-cartier
# Processing Record 2 of Set 12 | elburg
# Processing Record 3 of Set 12 | aksu
# Processing Record 4 of Set 12 | sarab
# Processing Record 5 of Set 12 | odessa
# Processing Record 6 of Set 12 | tuatapere
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | adilabad
# Processing Record 9 of Set 12 | lons
# Processing Record 10 of Set 12 | arlit
# Processing Record 11 of Set 12 | coari
# Processing Record 12 of Set 12 | toamasina
# Processing Record 13 of Set 12 | roseburg
# Processing Record 14 of Set 12 | inuvik
# Processing Record 15 of Set 12 | pauini
# Processing Record 16 of Set 12 | kedrovyy
# Processing Record 17 of Set 12 | grindavik
# Processing Record 18 of Set 12 | portland
# Processing Record 19 of Set 12 | otse
# Processing Record 20 of Set 12 | ust-ilimsk
# Processing Record 21 of Set 12 | herndon
# Processing Record 22 of Set 12 | kawalu
# Processing Record 23 of Set 12 | paracatu
# Processing Record 24 of Set 12 | doka
# Processing Record 25 of Set 12 | treinta y tres
# Processing Record 26 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 12 | ndjole
# Processing Record 28 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 29 of Set 12 | ambatofinandrahana
# Processing Record 30 of Set 12 | keti bandar
# Processing Record 31 of Set 12 | kavaratti
# Processing Record 32 of Set 12 | krasnokamensk
# Processing Record 33 of Set 12 | lyubim
# Processing Record 34 of Set 12 | roald
# Processing Record 35 of Set 12 | ust-maya
# Processing Record 36 of Set 12 | sechura
# Processing Record 37 of Set 12 | abu dhabi
# Processing Record 38 of Set 12 | marathopolis
# City not found. Skipping...
# Processing Record 39 of Set 12 | vicosa
# Processing Record 40 of Set 12 | racine
# Processing Record 41 of Set 12 | yulara
# Processing Record 42 of Set 12 | mogadishu
# Processing Record 43 of Set 12 | otofuke
# Processing Record 44 of Set 12 | yokadouma
# Processing Record 45 of Set 12 | magadan
# Processing Record 46 of Set 12 | vagur
# Processing Record 47 of Set 12 | kendari
# Processing Record 48 of Set 12 | handwara
# City not found. Skipping...
# Processing Record 49 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 12 | kolobrzeg
# Processing Record 1 of Set 13 | srednekolymsk
# Processing Record 2 of Set 13 | boende
# Processing Record 3 of Set 13 | hede
# Processing Record 4 of Set 13 | kavieng
# Processing Record 5 of Set 13 | mzimba
# Processing Record 6 of Set 13 | port moresby
# Processing Record 7 of Set 13 | boddam
# Processing Record 8 of Set 13 | goure
# Processing Record 9 of Set 13 | pangai
# Processing Record 10 of Set 13 | hlotse
# Processing Record 11 of Set 13 | navolato
# Processing Record 12 of Set 13 | nantucket
# Processing Record 13 of Set 13 | laguna
# Processing Record 14 of Set 13 | zheleznodorozhnyy
# Processing Record 15 of Set 13 | kovdor
# Processing Record 16 of Set 13 | toppenish
# Processing Record 17 of Set 13 | panjwin
# City not found. Skipping...
# Processing Record 18 of Set 13 | okha
# Processing Record 19 of Set 13 | tiarei
# Processing Record 20 of Set 13 | redcliffe
# Processing Record 21 of Set 13 | tasgaon
# Processing Record 22 of Set 13 | labranzagrande
# Processing Record 23 of Set 13 | dusti
# Processing Record 24 of Set 13 | taksimo
# Processing Record 25 of Set 13 | mahon
# Processing Record 26 of Set 13 | los lunas
# Processing Record 27 of Set 13 | kansanshi
# Processing Record 28 of Set 13 | santa maria
# Processing Record 29 of Set 13 | honiara
# Processing Record 30 of Set 13 | yima
# Processing Record 31 of Set 13 | udachnyy
# Processing Record 32 of Set 13 | panaba
# Processing Record 33 of Set 13 | dongkan
# Processing Record 34 of Set 13 | altagracia de orituco
# Processing Record 35 of Set 13 | saint-augustin
# Processing Record 36 of Set 13 | ferme-neuve
# Processing Record 37 of Set 13 | sile
# Processing Record 38 of Set 13 | kemijarvi
# Processing Record 39 of Set 13 | mecca
# Processing Record 40 of Set 13 | acapulco
# Processing Record 41 of Set 13 | franca
# Processing Record 42 of Set 13 | bud
# Processing Record 43 of Set 13 | jeremoabo
# Processing Record 44 of Set 13 | constantine
# Processing Record 45 of Set 13 | banepa
# Processing Record 46 of Set 13 | dzhebariki-khaya
# Processing Record 47 of Set 13 | maragogi
# Processing Record 48 of Set 13 | bolonchen
# City not found. Skipping...
# Processing Record 49 of Set 13 | tottori
# Processing Record 50 of Set 13 | isla vista
# Processing Record 1 of Set 14 | rocha
# Processing Record 2 of Set 14 | kibungo
# Processing Record 3 of Set 14 | hinton
# Processing Record 4 of Set 14 | southbridge
# Processing Record 5 of Set 14 | visnes
# Processing Record 6 of Set 14 | qeshm
# Processing Record 7 of Set 14 | kamenka
# Processing Record 8 of Set 14 | cherskiy
# Processing Record 9 of Set 14 | mumford
# Processing Record 10 of Set 14 | otjimbingwe
# Processing Record 11 of Set 14 | saint-louis
# Processing Record 12 of Set 14 | deep river
# Processing Record 13 of Set 14 | bartica
# Processing Record 14 of Set 14 | aswan
# Processing Record 15 of Set 14 | macapa
# Processing Record 16 of Set 14 | zelenogorskiy
# Processing Record 17 of Set 14 | omboue
# Processing Record 18 of Set 14 | kita
# Processing Record 19 of Set 14 | channel-port aux basques
# Processing Record 20 of Set 14 | arvin
# Processing Record 21 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 22 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 14 | tutayev
# Processing Record 25 of Set 14 | bolama
# Processing Record 26 of Set 14 | inongo
# Processing Record 27 of Set 14 | ossora
# Processing Record 28 of Set 14 | mount isa
# Processing Record 29 of Set 14 | changji
# Processing Record 30 of Set 14 | beringovskiy
# Processing Record 31 of Set 14 | sao jose da coroa grande
# Processing Record 32 of Set 14 | bonavista
# Processing Record 33 of Set 14 | nikolayevka
# Processing Record 34 of Set 14 | mangan
# Processing Record 35 of Set 14 | cheyur
# City not found. Skipping...
# Processing Record 36 of Set 14 | joaima
# Processing Record 37 of Set 14 | lata
# Processing Record 38 of Set 14 | ocos
# Processing Record 39 of Set 14 | sabla
# Processing Record 40 of Set 14 | wawa
# Processing Record 41 of Set 14 | port-gentil
# Processing Record 42 of Set 14 | ust-nera
# Processing Record 43 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 14 | richards bay
# Processing Record 45 of Set 14 | palizada
# Processing Record 46 of Set 14 | ndele
# Processing Record 47 of Set 14 | praya
# Processing Record 48 of Set 14 | yar-sale
# Processing Record 49 of Set 14 | labuhan
# Processing Record 50 of Set 14 | benghazi
# Processing Record 1 of Set 15 | keta
# Processing Record 2 of Set 15 | baruun-urt
# Processing Record 3 of Set 15 | makakilo city
# Processing Record 4 of Set 15 | long beach
# Processing Record 5 of Set 15 | teknaf
# Processing Record 6 of Set 15 | jalu
# Processing Record 7 of Set 15 | nouakchott
# Processing Record 8 of Set 15 | potsdam
# Processing Record 9 of Set 15 | puerto palomas
# Processing Record 10 of Set 15 | kamina
# Processing Record 11 of Set 15 | conde
# Processing Record 12 of Set 15 | salym
# Processing Record 13 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 15 | arman
# Processing Record 15 of Set 15 | monte gordo
# Processing Record 16 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 17 of Set 15 | waingapu
# Processing Record 18 of Set 15 | le port
# Processing Record 19 of Set 15 | bemidji
# Processing Record 20 of Set 15 | barraute
# Processing Record 21 of Set 15 | nome
# Processing Record 22 of Set 15 | sola
# Processing Record 23 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 24 of Set 15 | tautira
# Processing Record 25 of Set 15 | aripuana
# Processing Record 26 of Set 15 | sibolga
# Processing Record 27 of Set 15 | rawa mazowiecka
# Processing Record 28 of Set 15 | masuguru
# Processing Record 29 of Set 15 | marawi
# Processing Record 30 of Set 15 | sorgun
# Processing Record 31 of Set 15 | tengushevo
# Processing Record 32 of Set 15 | bassila
# Processing Record 33 of Set 15 | pandan
# Processing Record 34 of Set 15 | two rivers
# Processing Record 35 of Set 15 | paamiut
# Processing Record 36 of Set 15 | kaele
# Processing Record 37 of Set 15 | rutana
# Processing Record 38 of Set 15 | kharan
# Processing Record 39 of Set 15 | gamba
# Processing Record 40 of Set 15 | dharchula
# Processing Record 41 of Set 15 | kargapolye
# City not found. Skipping...
# Processing Record 42 of Set 15 | nabire
# Processing Record 43 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 15 | zhovkva
# Processing Record 45 of Set 15 | daru
# Processing Record 46 of Set 15 | calabozo
# Processing Record 47 of Set 15 | neuquen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Upernavik      GL  72.7868  -56.1549     26.91        79
# 1          Hermanus      ZA -34.4187   19.2345     67.80        64
# 2         Hithadhoo      MV  -0.6000   73.0833     81.91        73
# 3       New Norfolk      AU -42.7826  147.0587     74.91        29
# 4           Mataura      NZ -46.1927  168.8643     55.47        67
# 5           Te Anau      NZ -45.4167  167.7167     55.36        66
# 6            Hobart      AU -42.8794  147.3294     75.27        50
# 7          Carballo      ES  43.2130   -8.6910     46.76        80
# 8          Tasiilaq      GL  65.6145  -37.6368     32.16        97
# 9  Candido De Abreu      BR -24.5669  -51.3333     67.08        95
#
#    Cloudiness  Wind Speed Current Description
# 0         100        2.77     overcast clouds
# 1          29        5.50    scattered clouds
# 2         100        8.41     overcast clouds
# 3          64        1.99       broken clouds
# 4         100        9.44     overcast clouds
# 5          99        3.98          light rain
# 6           0       13.80           clear sky
# 7          13        2.86          few clouds
# 8         100       14.61                snow
# 9           0        1.61           clear sky

# %%
# Export the DataFrame as a CSV file
city_data_df.to_csv("WeatherPy_Database.csv", index=False)
